# %% [markdown]
# ## importing modules⬇️

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_olympics.csv')
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %% [markdown]
# # Duplicate dataset ⬇️

# %%
df1 = df.copy()
df1
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %% [markdown]
# ## TO SEE THE COLUMNS NAMES  ⬇️

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# # DATA TYPES ⬇️

# %%
df1.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %% [markdown]
# ## TO KNOW THE SHAPE OF THE DATASET ⬇️

# %%
df1.shape
# Out:
# (70000, 15)

# %% [markdown]
# # TO GET THE INFORMATION OF A DATASET ⬇️

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      70000 non-null  int64
#  1   Name    70000 non-null  object
#  2   Sex     70000 non-null  object
#  3   Age     67268 non-null  float64
#  4   Height  53746 non-null  float64
#  5   Weight  52899 non-null  float64
#  6   Team    70000 non-null  object
#  7   NOC     70000 non-null  object
#  8   Games   70000 non-null  object
#  9   Year    70000 non-null  int64
#  10  Season  70000 non-null  object
#  11  City    70000 non-null  object
#  12  Sport   70000 non-null  object
#  13  Event   70000 non-null  object
#  14  Medal   9690 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 8.0+ MB

# %%
df1.describe()
# Out:
#                  ID           Age        Height        Weight          Year
# count  70000.000000  67268.000000  53746.000000  52899.000000  70000.000000
# mean   18081.846986     25.644645    175.505303     70.900216   1977.766457
# std    10235.613253      6.485239     10.384203     14.217489     30.103306
# min        1.000000     11.000000    127.000000     25.000000   1896.000000
# 25%     9325.750000     21.000000    168.000000     61.000000   1960.000000
# 50%    18032.000000     25.000000    175.000000     70.000000   1984.000000
# 75%    26978.000000     28.000000    183.000000     79.000000   2002.000000
# max    35658.000000     88.000000    223.000000    214.000000   2016.000000

# %%
df1.describe(include='O')
# Out:
#                                     Name    Sex           Team    NOC  \
# count                              70000  70000          70000  70000
# unique                             35556      2            827    226
# top     Oksana Aleksandrovna Chusovitina      M  United States    USA
# freq                                  29  51877           4979   5216
#
#               Games  Season    City      Sport                    Event Medal
# count         70000   70000   70000      70000                    70000  9690
# unique           51       2      42         65                      744     3
# top     2016 Summer  Summer  London  Athletics  Football Men's Football  Gold
# freq           3675   58467    6034      10629                     1738  3292

# %%
df1.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2732
# Height    16254
# Weight    17101
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     60310
# dtype: int64

# %%
df.head()
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %% [markdown]
# # Assigning winter olympics season  to df for better analysis

# %%
Winter_df = df[df['Season']=='Winter']
Winter_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# ...

# %% [markdown]
# # shape of winter olympics

# %%
Winter_df.shape
# Out:
# (11533, 15)

# %% [markdown]
# # Gender distribution

# %%
sns.countplot(data=Winter_df,x='Sex')
plt.title('Gender Distribution of Winter Olympics Athletes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Top 10 countries by participation

# %%
top_countries=Winter_df['Team'].value_counts().head(10)
plt.figure(figsize=(10,5))
top_countries.plot(kind='bar')
plt.title('Top 10 countries by winter Olympics Participation')
plt.xlabel('country')
plt.ylabel('Number of Athletes')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Most popular winter sports

# %%
top_sports = Winter_df['Sport'].value_counts().head(10)
plt.figure(figsize=(10,5))
top_sports.plot(kind='bar')
plt.title('Top 10 most popular winter Sports')
plt.xlabel('Sport')
plt.ylabel('Number of Athletes')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Athletes participation over the tear

# %%
year_participation = Winter_df.groupby('Year')['ID'].count()
plt.figure(figsize=(10,5))
year_participation.plot(kind='line')
plt.title('Winter Olympics Athletes Participation Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Athletes')
plt.show()

# %%
year_participation = Winter_df.groupby('Year')['ID'].count()

plt.figure(figsize=(10,5))
year_participation.plot(kind='line')
plt.title('Winter Olympics Athlete Participation Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Athletes')
plt.show()

# %% [markdown]
# # Machine learning

# %%
Winter_df['Medal_won']= Winter_df['Medal'].notnull().astype(int)
Winter_df['Medal_won'].value_counts()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5172\849284678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Winter_df['Medal_won']= Winter_df['Medal'].notnull().astype(int)
# Medal_won
# 0    10247
# 1     1286
# Name: count, dtype: int64

# %%
Winter_df
# Out:
#           ID                      Name Sex   Age  Height  Weight  \
# 4          5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5          5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6          5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7          5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8          5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...      ...                       ...  ..   ...     ...     ...
# 69991  35653     Casey J. FitzRandolph   M  31.0   180.0    79.0
# 69994  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69995  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69999  35658              Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 4         Netherlands  NED  1988 Winter  1988  Winter      Calgary
# ...

# %%
Winter_df
# Out:
#           ID                      Name Sex   Age  Height  Weight  \
# 4          5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5          5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6          5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7          5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8          5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...      ...                       ...  ..   ...     ...     ...
# 69991  35653     Casey J. FitzRandolph   M  31.0   180.0    79.0
# 69994  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69995  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69999  35658              Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 4         Netherlands  NED  1988 Winter  1988  Winter      Calgary
# ...

# %%
Winter_df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'Medal_won'],
#       dtype='object')

# %%
Winter_df = Winter_df.drop(
    ['ID','Name','Games','City','Medal'],
    axis = 1,
    errors = 'ignore'
)

# %%
Winter_df.columns
# Out:
# Index(['Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Year', 'Season',
#        'Sport', 'Event', 'Medal_won'],
#       dtype='object')

# %% [markdown]
# # checking the missing values

# %%
Winter_df.isnull().sum()
# Out:
# Sex             0
# Age            66
# Height       2272
# Weight       2453
# Team            0
# NOC             0
# Year            0
# Season          0
# Sport           0
# Event           0
# Medal_won       0
# dtype: int64

# %%
Winter_df['Age'].fillna(Winter_df['Age'].median(),inplace=True)
Winter_df['Height'].fillna(Winter_df['Height'].median(),inplace=True)
Winter_df['Weight'].fillna(Winter_df['Weight'].median(),inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5172\691243787.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Winter_df['Age'].fillna(Winter_df['Age'].median(),inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_5172\691243787.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
Winter_df.columns
# Out:
# Index(['Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Year', 'Season',
#        'Sport', 'Event', 'Medal_won'],
#       dtype='object')

# %%
Winter_df.isnull().sum()
# Out:
# Sex          0
# Age          0
# Height       0
# Weight       0
# Team         0
# NOC          0
# Year         0
# Season       0
# Sport        0
# Event        0
# Medal_won    0
# dtype: int64

# %% [markdown]
# # Encoding categories converting text into numbers

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_cols=[
    'Sex','Team','NOC',
    'Season','Sport','Event'
]
for col in categorical_cols:
    Winter_df[col]=le.fit_transform(
        Winter_df[col].astype(str)
    )
Winter_df.head()
# Out:
#    Sex   Age  Height  Weight  Team  NOC  Year  Season  Sport  Event  Medal_won
# 4    0  21.0   185.0    82.0   105   64  1988       0     16    117          0
# 5    0  21.0   185.0    82.0   105   64  1988       0     16    113          0
# 6    0  25.0   185.0    82.0   105   64  1992       0     16    117          0
# 7    0  25.0   185.0    82.0   105   64  1992       0     16    113          0
# 8    0  27.0   185.0    82.0   105   64  1994       0     16    117          0

# %% [markdown]
# # seperating features and target

# %%
x = Winter_df.drop('Medal_won',axis=1)
y = Winter_df['Medal_won']
x
# Out:
#        Sex   Age  Height  Weight  Team  NOC  Year  Season  Sport  Event
# 4        0  21.0   185.0    82.0   105   64  1988       0     16    117
# 5        0  21.0   185.0    82.0   105   64  1988       0     16    113
# 6        0  25.0   185.0    82.0   105   64  1992       0     16    117
# 7        0  25.0   185.0    82.0   105   64  1992       0     16    113
# 8        0  27.0   185.0    82.0   105   64  1994       0     16    117
# ...    ...   ...     ...     ...   ...  ...   ...     ...    ...    ...
# 69991    1  31.0   180.0    79.0   161   94  2006       0     16    106
# 69994    1  19.0   175.0    70.0    59   31  1976       0      0      1
# 69995    1  19.0   175.0    70.0    59   31  1976       0      0      2
# 69996    1  19.0   175.0    70.0    59   31  1976       0      0      3
# 69999    1  23.0   180.0    68.0    36   21  1998       0     11     79
#
# [11533 rows x 10 columns]

# %%
y
# Out:
# 4        0
# 5        0
# 6        0
# 7        0
# 8        0
#         ..
# 69991    0
# 69994    0
# 69995    0
# 69996    0
# 69999    0
# Name: Medal_won, Length: 11533, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.2,random_state=42)
x_train
# Out:
#        Sex   Age  Height  Weight  Team  NOC  Year  Season  Sport  Event
# 11155    1  28.0   177.0    68.0   128   77  2002       0      6     54
# 69380    0  22.0   178.0    70.0   145   84  1976       0     16    114
# 69633    0  22.0   164.0    52.0    23   14  1976       0      4     46
# 44479    0  37.0   176.0    65.0     6    5  2010       0      7     63
# 12440    1  23.0   189.0    72.0   117   71  1988       0     11     75
# ...    ...   ...     ...     ...   ...  ...   ...     ...    ...    ...
# 68996    1  24.0   170.0    67.0   117   71  1968       0     14     92
# 30863    1  27.0   188.0    70.0    61   31  2002       0      3     26
# 31930    0  26.0   166.0    61.0   127   77  2010       0      2     17
# 6952     0  23.0   179.0    74.0   145   84  2006       0      8     69
# 45114    1  19.0   180.0    80.0     6    5  1992       0      7     60
#
# [9226 rows x 10 columns]

# %%
x_test
# Out:
#        Sex   Age  Height  Weight  Team  NOC  Year  Season  Sport  Event
# 69397    1  27.0   175.0    82.0    76   45  2010       0      0      0
# 7408     1  23.0   165.0    70.0    59   31  1964       0      4     31
# 22232    0  18.0   175.0    70.0     2    3  1984       0      0      8
# 39813    1  26.0   175.0    70.0    33   18  1992       0      0      2
# 69396    1  27.0   175.0    82.0    76   45  2010       0      0      4
# ...    ...   ...     ...     ...   ...  ...   ...     ...    ...    ...
# 34280    1  32.0   175.0    70.0    77   45  1948       0      3     24
# 23023    1  19.0   175.0    70.0    13    8  1972       0      0      1
# 7167     0  19.0   168.0    53.0    44   32  1980       0      4     45
# 36020    1  29.0   175.0    70.0    50   29  1956       0      4     31
# 48287    0  21.0   168.0    66.0   145   84  2014       0      7     67
#
# [2307 rows x 10 columns]

# %%
y_train
# Out:
# 11155    1
# 69380    0
# 69633    0
# 44479    0
# 12440    0
#         ..
# 68996    0
# 30863    0
# 31930    0
# 6952     1
# 45114    0
# Name: Medal_won, Length: 9226, dtype: int32

# %%
y_test
# Out:
# 69397    0
# 7408     0
# 22232    0
# 39813    0
# 69396    0
#         ..
# 34280    0
# 23023    0
# 7167     1
# 36020    0
# 48287    0
# Name: Medal_won, Length: 2307, dtype: int32

# %%
Winter_df = Winter_df.drop(
    ['Name'],
    axis=1,
    errors='ignore'
)

# %% [markdown]
# # model training

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # model prediction

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # checking of accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)
print('Accuracy:',accuracy)
# Out:
# Accuracy: 0.905504984828782

# %% [markdown]
# # classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      2054
#            1       0.61      0.38      0.47       253
#
#     accuracy                           0.91      2307
#    macro avg       0.77      0.67      0.71      2307
# weighted avg       0.89      0.91      0.90      2307

# %% [markdown]
# # comfution matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True,fmt='d')
plt.title('confusion matrix')
plt.xlabel('predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # creating x and y

# %%
x = Winter_df.drop('Medal_won',axis=1)
y = Winter_df['Medal_won']
x
# Out:
#        Sex   Age  Height  Weight  Team  NOC  Year  Season  Sport  Event
# 4        0  21.0   185.0    82.0   105   64  1988       0     16    117
# 5        0  21.0   185.0    82.0   105   64  1988       0     16    113
# 6        0  25.0   185.0    82.0   105   64  1992       0     16    117
# 7        0  25.0   185.0    82.0   105   64  1992       0     16    113
# 8        0  27.0   185.0    82.0   105   64  1994       0     16    117
# ...    ...   ...     ...     ...   ...  ...   ...     ...    ...    ...
# 69991    1  31.0   180.0    79.0   161   94  2006       0     16    106
# 69994    1  19.0   175.0    70.0    59   31  1976       0      0      1
# 69995    1  19.0   175.0    70.0    59   31  1976       0      0      2
# 69996    1  19.0   175.0    70.0    59   31  1976       0      0      3
# 69999    1  23.0   180.0    68.0    36   21  1998       0     11     79
#
# [11533 rows x 10 columns]

# %%
y
# Out:
# 4        0
# 5        0
# 6        0
# 7        0
# 8        0
#         ..
# 69991    0
# 69994    0
# 69995    0
# 69996    0
# 69999    0
# Name: Medal_won, Length: 11533, dtype: int32

# %% [markdown]
# # feature importance

# %%
feature_importance = pd.DataFrame({
    'feature':x.columns,
    'importance':model.feature_importances_
})
feature_importance = feature_importance.sort_values(
    by = 'importance',
    ascending=False
)
plt.figure(figsize=(8,5))
plt.barh(
    feature_importance['feature'],
    feature_importance['importance']
)
plt.title('feature importance')
plt.xlabel('importance score')
plt.show()

# %% [markdown]
# # Project summary and conclusion

# %%
# This project analyzed winter olympics dataset to explore athletes participation,
# sports trends,and medal performance.data visualization was used to examine gender 
# distribution,top participating countries,popular winter sports,and athletes participation over the 
# year.A machine learning model was developed to predict if an athlete won medal based on factor such as 
# age,gender,sports,event,country and year.after the data cleaning proccesing and encoding categories,a random forest classifier
# was train and evaluated.the model achieved accuracy score of 90.38% indicating strong predictive performance.
# feature importance analysis also helped identified the factors that most influenced medal out comes.

# %% [markdown]
# # Conclusion

# %%
# This project demonstrated how data analysis and machine learning can be applied
# to sports data to uncover patterns and predict athletes performance .
# The findings provide valuable insight inti winter olympics participation
# and medal achievement trends.
